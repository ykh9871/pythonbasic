# %% [markdown]
# # Matplotllib이란

# %% [markdown]
# ##### 파이썬에서자료를 차트나 플롯으로 시각화 하는 패키지입니다.
# - 라인 플롯
# - 스캐터 플롯
# - 컨투어 플롯
# - 서피스
# - 바
# - 히스토그램
# - 박스 플롯

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Matplotlib 및 Matplotlib.pyplot 임포트하기

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ### 만약 그래프가 출력되지 않는다면
# 주피터 랩에서는 별도의 윈도우를 띄워서 Figure를 표현하지 않습니다.
# 이 때문에 경우에 따라서 그래프가 출력되지 않는 경우가 발생됩니다.
# 그때는 다음처럼 %matplotlib 매직 명령으로 주피터 내부에 그림을 표시하도록 지정해야합니다.

# %%
# %matplotlib inline

# %% [markdown]
# ### 라인 플롯(line plot) - title(), x 축의 위치(tick), show()
# - title()는 플롯의 제목입니다.
# - x축의 위치를 x틱이라고 합니다. default는 0,1....N-1범위의 index array입니다.
# - x tick을 지정하려면 두 개의 같은 길이의 리스트ㅡ 혹은 배열 자려를 넣으면 됩니다.
# - show는 플롯을 그림으로 표시합니다.

# %%
plt.title("Plot")
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title("x ticks")
plt.plot([10,20,30,40], [1,4,9,16])
plt.show()

# %% [markdown]
# ### 폰트

# %% [markdown]
# #### 한글 폰트 사용하기
# - 한글 제목을 사용하기 위해 title()의 인수로 한글 문자열을 전달하면 아래처럼 제대로 표현되지 않음을 확인할 수 있습니다.

# %%
plt.title("한글 제목")
plt.plot([10,20,30,40], [1,4,9,16])
plt.show()
# Out:
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##### Font 설치하기
# 1. 폰트를 다운로드 받습니다.
#     - 무료 폰트 사이트 : [https://noonnu.cc/]
# 2. 다운로드 받은 폰트를 실행하면 설치할 수 있습니다.
# 3. 리눅스
# !sudo apt instasll -y fonts-nanum*
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# ##### font_manager
# - 설치된 폰트를 조회할 수 있습니다.

# %%
import matplotlib.font_manager
font_list = matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

# %%
[matplotlib.font_manager.FontProperties(fname=font).get_name() for font in font_list if 'Batang' in font]
# Out:
# []

# %%
font_list = matplotlib.font_manager.findSystemFonts()
font_list
# Out:
# ['C:\\Windows\\Fonts\\pala.ttf',
#  'C:\\Windows\\Fonts\\Candaraz.ttf',
#  'C:\\Windows\\Fonts\\georgia.ttf',
#  'C:\\WINDOWS\\Fonts\\arialbi.ttf',
#  'C:\\Windows\\Fonts\\comici.ttf',
#  'C:\\WINDOWS\\Fonts\\batang.ttc',
#  'C:\\WINDOWS\\Fonts\\webdings.ttf',
#  'C:\\WINDOWS\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\WINDOWS\\Fonts\\taileb.ttf',
#  'C:\\Windows\\Fonts\\calibrib.ttf',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\Windows\\Fonts\\framdit.ttf',
#  'C:\\WINDOWS\\Fonts\\cambriab.ttf',
#  'C:\\WINDOWS\\Fonts\\Candarai.ttf',
#  'C:\\WINDOWS\\Fonts\\georgiab.ttf',
#  'C:\\Windows\\Fonts\\segoeprb.ttf',
#  'C:\\WINDOWS\\Fonts\\javatext.ttf',
#  'C:\\WINDOWS\\Fonts\\calibril.ttf',
#  'C:\\Windows\\Fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\verdanab.ttf',
#  'C:\\WINDOWS\\Fonts\\trebuc.ttf',
#  'C:\\WINDOWS\\Fonts\\mmrtext.ttf',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\cambriab.ttf',
#  'C:\\Windows\\Fonts\\seguisb.ttf',
# ...

# %% [markdown]
# ##### Font scope
# 설치된 폰트를 사용하는 방법은 크게 두가지 입니다.
# - mpl.rc('font', family='폰트명')메서드를 통한 설정으로 전체 범위에 대해 적용하기
# 위 코드는 mpl.rcParams["font.family"] = '폰트명' 과 같습니다.
# - fontdict keyword argument를 사용하여 세부적으로 적용하는 방벅

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from pathlib import Path

# %%
mpl.rcParams['axes.unicode_minus'] = False
mpl.rcParams["font.family"] = 'Batang'
# mpl.rc('font',family='Batang')

# %%
import matplotlib.font_manager as font_manager
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['C:/python/fonts']
for font in font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    font_manager.fontManager.addfont(font)
# Set font family globally
mpl.rcParams['font.family'] = 'Nanum Pen'
print(mpl.rcParams['font.family'])
# Out:
# Nanum Pen
# NanumGothic
# ['Nanum Pen']

# %%
plt.title("한글 제목")
plt.plot([10,20,30,40], [1,4,9,16])
plt.show()

# %% [markdown]
# #### matplotlib.pyplot.rc()

# %% [markdown]
# - 한글 문자열은 항상 유니코드(e.g. UTF-8)를 사용해야 합니다. 우선 우리가 학습하는
# 동안 전체 범위에서 한글을 사용하기 위해서 mlp.rc()를 통하여 전체 영역에 대한 폰트
# 설정을 변경해줍니다.
# mlp.rc(‘rcParams’, 변경할 값을 키워드 인수로 전달)는 rcParams를 변경해주는
# 메서드입니다.

# %% [markdown]
# #### 기본 폰트 설정

# %%
global_font = {'family':'Batang', 'size':12, 'weight': 'bold'}

# 폰트 설정
mpl.rc('font',**global_font) # pass in the font divt as kwargs
# mpl.rc('font', family' = 'Batang', 'size':=24, 'weight': 'bold')와 같이 동작합니다.

# %% [markdown]
# #### RcParams 중 font
# ![image.png](attachment:9c92deba-c55c-4779-a794-bb9a13d24d42.png)

# %% [markdown]
# #### 기본 폰트 확인

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40], [1,4,9,16])
plt.xlabel("엑스축 레이블")
plt.ylabel("와이축축 레이블")
plt.show()

# %% [markdown]
# #### 개별 폰트 설정하기

# %%
title_font = {'family' : 'Batang',
              'size' : 24,
              'color' : 'black'}
xlabel_font = {'family' : 'Nanum Pen',
              'size' : 18,
              'weight' : 'bold',
              'color' : 'darkred'}
ylabel_font = {'family' : 'NanumGothic',
              'size' : 12,
              'weight' : 'light',
              'color' : 'blue'}

plt.plot([10,20,30,40], [1,4,9,16])
plt.title('한글 제목', fontdict=title_font)
plt.xlabel('엑스 축', fontdict=xlabel_font)
plt.ylabel('와이 축', fontdict=ylabel_font)
plt.show()

# %% [markdown]
# #### Unicode minus 표기법 설정

# %%
# 유니코드에서 음수 부호설정
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### Style 설정하기

# %%
plt.title("default 스타일의 plot ")
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %%
plt.title("'rs--' 스타일의 plot ")
plt.plot([10,20,30,40],[1,4,9,16], 'rp--')
plt.show()

# %% [markdown]
# #### Style 설정하는 순서
# 색상, 마커, 선 종류의 순서로 지정한다. 만약 이 중 일부가 생략되면 디폴트값이 적용됩니다.

# %% [markdown]
# ##### color

# %% [markdown]
# ![image.png](attachment:abe3f0ad-3c21-4bbb-9026-c60cc50266a7.png)

# %% [markdown]
# ##### marker
# - 데이터 위치를 나타내는 기호를 마커(marker)라고 한다.

# %% [markdown]
# ![image.png](attachment:18987da8-578a-4e6c-a8dd-35827250768c.png)![image.png](attachment:82a244de-3c68-464e-b230-a3a54d45a6e1.png)

# %% [markdown]
# ##### linestyle
# - 선 스타일의 지정 문자열은 다음과 같다.

# %% [markdown]
# ![image.png](attachment:f9de5644-87a0-4041-a1d3-497f6b57de4c.png)

# %% [markdown]
# ##### 기타 style

# %%
plt.plot([10,20,30,40],[1,4,9,16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.show()

# %% [markdown]
# ### 축의 범위 설정하기

# %%
plt.title("x축, y축의 범위 설정")
plt.plot([10,20,30,40],[1,4,9,16], 
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %% [markdown]
# ### 틱 설정하기

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("x축과 y축의 tick label 설정")
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1,0,+1])
plt.show()

# %% [markdown]
# #### ![image.png](attachment:f0cbf4b3-4980-406e-ad35-312103fe750e.png)

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("Tex, 문자열로 tic label 정의")
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1,0,+1], ["Low", "Zero", "High"])
plt.show()

# %% [markdown]
# ### 여러 개의 선 그리기

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t,t,'r--',t,0.5*t**2,'bs:',t,0.2*t**3,'g^-')
plt.show()

# %%
plt.title("복수의 plot 명령을 한 그림에서 표현")
style1 =  {"c":"b", "lw":5, "ls": "--", "marker":"o","ms":15,"mec":"g","mew":5,"mfc":"r"}
style2 =  {"c":"k", "lw":3, "ls": ":", "marker":"s","ms":10,"mec":"m","mew":5,"mfc":"c"}

plt.plot([1,4,9,16], **style1)
plt.plot([9,16,4,1], **style2)

plt.show()

# %% [markdown]
# ### 범례(Legend)
# 여러개의 라인 플롯을 동시에 그리는 경우에는 각 선이 무슨 자료를 표시하는지를
# 보여주기 위해 legend 명령으로 범례를 추가할 수 있습니다. 범례의 위치는 자동으로 정해지지만
# 수동으로 설정하고 싶으면 loc키워드 인수를 사용합니다.

# %% [markdown]
# ![image.png](attachment:8feae432-b180-49f3-8ebd-3a1c78659ba3.png)

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S= np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2) # upper left
plt.show()

# %% [markdown]
# ### x,y 축 label

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S= np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %% [markdown]
# ### 내용요약

# %% [markdown]
# ####
# ![image.png](attachment:6493fbc9-7083-4511-87a9-148f06ef88dd.png)
# ![image.png](attachment:1357add9-e254-4d19-9107-d1240b1d341a.png)

# %% [markdown]
# ### Figure

# %% [markdown]
# #### Figure, Axes 객체를 만드는 방법은 pyplot.subplot()을 사용하는 것입니다.
# 그후 Axes.plot()를 활용하여 Axes에 데이터를 그립니다.

# %%
fig, ax = plt.subplots() # Create a figure contanining a single axes.
ax.plot([1,2,3,4],[1,4,2,3]); # Plot some data on the axes

# %% [markdown]
# #### Figure는 전체 그림을 의미하는 객체 입니다.

# %%
fig = plt.figure() # an empty figure with no Axes
fig, ax = plt.subplots() # a figure with a single Axes
fig, axs = plt.subplots(2,2) # a figure with a 2x2 grid of Axes

# %% [markdown]
# #### plt.plot()

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10,2))
plt.title("figure size : (10,2)")
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# #### Figure- plt.show()가 그래프를 그리는 방식의 차이

# %% [markdown]
# ipython의 형태인 주피터 랩에서 show() 메서드를 통해 그래프를 그려보면
# 별도의 Window 객체를 생성하지 않고 jupyter widget으로 결과를 보여줍니다.
# 반대로 파이썬을 독립 실행하는 경우에는 하나의 Figure당 하나의 Window를 별도로 가집니다.
# 이 때 Matplotlib backends는 Figure windows에 대한 확대 및 축소 기능을 지원합니다.

# %% [markdown]
# #### Figure 객체 얻기 plt.gcf()

# %%
f1 = plt.figure(1)
plt.title("현재의 Figure 객체")
plt.plot([1,2,3,4], 'ro:')
f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 1299464873440
# Figure(640x480) 1299464873440

# %% [markdown]
# ### Axes

# %%
ax1 = plt.subplot(2,1,1)
# 여기에서 윗부분에 그릴 플롯 명령 실행
ax2= plt.subplot(2,1,2)
# 여기에서 아랫부분에 그릴 플롯 명령 실행

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi *x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi *x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1,y1,'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2,1,2)
plt.plot(x2,y2,'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
# tight_layout() 명령을 실행하면 플롯 간의 간격을 자동으로 맞춰줍니다.
plt.tight_layout()
plt.show()

# %%
# Axes의 순서는 콘솔 출력 순서와 동일합니다(좌에서 우로, 위에서 아래로).
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %%
# subplots()에 인수를 두개만 전달하면 복수의 Axes 객체를 동시에 생성할 수도 있습니다.
# 이때는 2차원 ndarray 형태로 Axes 객체가 반환됩니다.
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Axes는 데이터 플로팅을 위한 영역으로 Figure에 포함되는 Artist입니다.
# 일반적으로 2차원의 경우 Axis 객체를 두 개 포함합니다.(3차원의 경우 Axis 객체를 세 개 포함)
# Axis는 ticks와 tick labels을 제공하며 이는 Axes의 데이터 범위에 대한 척도가 됩니다.
# - Axes와 Axis는 다른 객체이므로 잘 구분해서 봐야 합니다.
# Axes 클래스와 그 메서드는 주요한 Entry point이며, 대부분의 플로팅 메서드가 정의되어 있습니다.

# %% [markdown]
# ### Axis

# %% [markdown]
# #### 하나의 Axes 객체는 두 개 이상의 Axis 객체를 가집니다.
# Axis 객체는 플롯의 가로축이나 세로축을 나타내는 객체입니다.
# Axis 객체는 ticks(축의 표시)과 ticklabels(눈금 레이블을 지정하는 문자열)에 대한 규모와 제한을 설정합니다.
# ticks의 위치는 Locator 객체에 의해 결정되며,
# 눈금 레이블 문자열은 Formatter 객체에 의해 형식이 지정됩니다.
# Locator와 Formatter 객체를 올바르게 조합하면 매우 세밀하게 tick 위치와 labels을 제어할 수 있습니다.

# %% [markdown]
# #### twinx 명령

# %%
# x 축을 공유하는 새로운 Axes 객체 만들기
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax0.set_ylabel("y1")
ax0.grid(False)
ax0.set_xlabel("공유되는 x축")
plt.show()

# %% [markdown]
# ### Artist

# %% [markdown]
# #### 기본적으로 Figure에 보이는 모든 것들을 Artist라고 합니다.
# 이는 Figure, Axes, Axis 객체도 포함됩니다.  또 Text 객체, Line2D 객체, collections 객체, Patch 객체 등도 포함됩니다.
# Figure가 렌더링될 때, 모든 Artists가 그려집니다. 대부분의 Artists는 하나의 Axes에 묶여있습니다.
# 이러한 Artists는 여러 Axes에 공유되거나 이동할 수 없습니다.

# %% [markdown]
# ### 바 차트

# %% [markdown]
# #### x 데이터가 카테고리 값인 경우에는 bar 명령과 barh 명령으로 바 차트(bar chart) 시각화를 할 수 있습니다.
# 가로 방향으로 바 차트를 그리려면 barh 명령을 사용합니다.
# - 바 차트 작성시 주의점은 첫번째 인수인 left 가 x축에서 바(bar)의 왼쪽 변의 위치를 나타낸다는 점입니다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

y = [2, 3, 1]
x = ['가', '나', '다']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %% [markdown]
# #### 바 색상적용
# 각 bar 마다 색상을 적용할 수 있습니다.
# 적용하고 싶은 색상을 데이터 순으로 리스트로 생성합니다.
# 생성한 리스트를 bar()의 color 키워드 인수로 전달하면 됩니다.
# 그러면 아래와 같은 색상을 갖는 바 차트를 완성할 수 있습니다.

# %%
y = [2, 3, 1]
x = ['가', '나', '다']
colors = ["red", "green", "blue"]

plt.title("Bar Chart")
plt.bar(x, y, color=colors)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %% [markdown]
# #### xerr 인수나 yerr 인수를 지정하면 에러 바(error bar)를 추가할 수 있습니다.
# 다음 코드에서 alpha는 투명도를 지정합니다. 0이면 완전 투명, 1이면 완전 불투명입니다.

# %%
np.random.seed(0)

people = ["몽룡", "춘향", "방자", "향단"]
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(people, performance, xerr=error, alpha=0.4)
plt.xlabel('x 라벨')
plt.show()

# %% [markdown]
# ### 파이 차트

# %% [markdown]
# #### 카테고리 별 값의 상대적인 비교를 해야 할 때는 pie 명령으로 파이 차트(pie chart)를 그릴 수 있습니다.

# %%
labels = ['월세', '전세', '자가', '기타']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal') # 원의 형태를 유지
plt.show()

# %% [markdown]
# ### 히스토그램

# %% [markdown]
# #### 히스토그램을 그리기 위한 hist 명령도 있습니다. hist 명령은 bins 인수로 데이터를 집계할 구간 정보를 받습니다.
# 반환값으로 데이터 집계 결과를 반환합니다.

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title("Hitogram")
arrays, bins, patches = plt.hist(x, bins=10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %% [markdown]
# ### 스캐터 플롯

# %% [markdown]
# #### 2차원 데이터, 즉 두 개의 실수 데이터 집합의 상관관계를 살펴보려면 scatter 명령으로 스캐터 플롯을 그립니다.
# 스캐터 플롯의 점 하나의 위치는 데이터 하나의 x, y 값입니다.

# %%
np.random.seed(0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title("Scatter Plot")
plt.scatter(X, Y)
plt.show()

# %% [markdown]
# #### 데이터가 2차원이 아니라 3차원 혹은 4차원인 경우에는 점 하나의 크기 혹은 색깔을 이용하여 다른 데이터 값을 나타낼 수도 있다.
# 이런 차트를 버블 차트(bubble chart)라고한다. 크기는 s 인수로 색깔은 c 인수로 지정한다.

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %% [markdown]
# ### imshow

# %% [markdown]
# #### 화상(image) 데이터처럼 행과 열을 가진 행렬 형태의 2차원 데이터는 imshow 명령을 써서
# 2차원 자료의 크기를 색깔로 표시하는 것이다.

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits; 0")
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %% [markdown]
# #### 데이터 수치를 색으로 바꾸는 함수는 칼라맵(color map)이라고 한다.
# 칼라맵은 cmap 인수로 지정한다.
# 사용할 수 있는 칼라맵은 plt.cm의 속성으로 포함되어 있다.
# 아래에일부 칼라맵을 표시하였다.

# %%
dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %% [markdown]
# #### 아래 예제는 cmap 키워드 인수를 사용하여 다양한 색상으로 변경된 결과를 출력하고 있습니다.

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 3),
                         subplot_kw={'xticks': [], 'yticks': []})
axes[0].set_title('plt.cm.Blues')
axes[0].imshow(X, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title('plt.cm.Blues_r')
axes[1].imshow(X, interpolation='nearest', cmap=plt.cm.Blues_r)
axes[2].set_title('plt.BrBG')
axes[2].imshow(X, interpolation='nearest', cmap='BrBG')
axes[3].set_title('plt.BrBG_r')
axes[3].imshow(X, interpolation='nearest', cmap='BrBG_r')
plt.show()

# %% [markdown]
# #### imshow 명령은 자료의 시각화를 돕기위해 다양한 2차원 인터폴레이션을 지원합니다.

# %%
methods = [
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
    'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
    'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos'
]
fig, axes = plt.subplots(3, 6, figsize=(12, 6),
                         subplot_kw={'xticks': [], 'yticks': []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap=plt.cm.bone_r, interpolation=interp_method)
    ax.set_title(interp_method)
plt.show()

# %% [markdown]
# ### 컨투어 플롯

# %% [markdown]
# #### 입력 변수가 x, y 두 개이고 출력 변수가 z 하나인 경우에는 3차원 자료가 된다. 3차원
# 자료를 시각화하는 방법은 명암이 아닌 등고선(contour)을 사용하는 방법이다. contour
# 혹은 contourf 명령을 사용한다. contour는 등고선만 표시하고 contourf는 색깔로
# 표시한다. 입력 변수 x, y는 그대로 사용할 수 없고 meshgrid 명령으로 그리드 포인트
# 행렬을 만들어야 한다.

# %%
def f(x, y):
    return(1 -x  / 2 + x ** 5 + y ** 3) *  np.exp(-x ** 2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

plt.title("Contour plots")
plt.contourf(XX, YY, ZZ, alpha=.75, cmap='jet')
plt.contour(XX, YY, ZZ, colors='black')
plt.show()

# %% [markdown]
# ### 3D 서피스 플롯

# %% [markdown]
# #### 3차원 플롯은 등고선 플롯과 달리 Axes3D라는 3차원 전용 axes를 생성하여 입체적으로 표시한다.
# plot_wireframe(), plot_surface() 명령을 사용한다.

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, ZZ, rstride=1, cstride=1, cmap='hot')
plt.show()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_13940\3016912474.py:9: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# ### 연습문제

# %% [markdown]
# #### 다음과 같은 그래프를 그려보세요.
# - title: 섭씨온도와 화씨온도
# - xlabel: 화씨 온도
# - ylabel: 섭씨 온도
# - x 값은 화씨로 32이상 ~ 100미만의 정수 y값은 섭씨로 ℃ = (℉-32)* 5/9 를 통해 구합니다.

# %%
F = np.arange(32,100)
C = (F-32)*5/9
plt.plot(F,C,'r-.')
plt.title("섭씨온도와 화씨온도")
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")
plt.show()

# %% [markdown]
# #### 타이타닉 데이터셋을 Seaborn 패키지로부터 불러오고, 사망자와 생존자를 Matplotlib의 바 차트로 표현해 보세요.

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.alive.value_counts()

alive = ["사망자", "생존자"]
total = titanic.alive.value_counts()
colors = ["red", "green"]

plt.title("타이타닉호 생존 여부")
plt.barh(alive, total, color=colors)
plt.xlabel('인원 수')
plt.show()

# %%
bar_chart = titanic.alive.value_counts()
bar_chart.rename({'no':'사망자', 'yes':'생존자'}, inplace=True)
bar_chart

alive = bar_chart.index
value = bar_chart.values
bar_colors = ["red", "green"]

plt.title("타이타닉호 생존 여부")
plt.barh(alive, value, color=bar_colors)
plt.xlabel('인원 수')
plt.show()

# %%
fig, ax = plt.subplots()

alive = bar_chart.index
value = bar_chart.values
bar_colors = ["red", "green"]

ax.set_title("타이타닉호 생존 여부")
plt.barh(alive, value, color=bar_colors)
plt.xlabel('인원 수')
plt.show()

# %% [markdown]
# #### 타이타닉호 승객을 '미성년자','청년','장년','중년','노년' 나이 그룹으로 나눕니다.
# 그리고 각 나이 그룹의 승객 비율을 파이 차트로 출력해보세요.
# - 단 NaN 값은 배제합니다.
# - 그림자 : True
# - 시작 각도: 90
# - autopct: '%1.1f%%'

# %%
import pandas as pd
import seaborn as sns
titanic = sns.load_dataset("titanic")

# %%
bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
titanic["age_cut"] = pd.cut(titanic_age.age,bins,labels=labels)
titanic.age_cut.value_counts(True)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
pie_chart = titanic.age_cut.value_counts(True)

labels = pie_chart.index
sizes = pie_chart.values
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]
explode = (0.1, 0, 0, 0, 0)

plt.title("Pie Chart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()
